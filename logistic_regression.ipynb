# %% [markdown]
# Q.1 Q1. Data Loading & Understanding
#
# a) Load the dataset into Python.
# b) Display the first 5 rows.
# c) Check the shape of the dataset.
# d) Display the data types of each column.
#
# ...>> # Import required libraries
# import pandas as pd
#
# # a) Load the dataset into Python
# # Replace 'your_dataset.csv' with your actual file name
# df = pd.read_csv('your_dataset.csv')
#
# # b) Display the first 5 rows
# print("First 5 Rows:")
# print(df.head())
#
# # c) Check the shape of the dataset
# print("\nShape of Dataset:")
# print(df.shape)
#
# # d) Display the data types of each column
# print("\nData Types of Each Column:")
# print(df.dtypes)
# Explanation
# pd.read_csv() → Loads the dataset.
# head() → Shows the first 5 rows.
# shape → Returns (rows, columns).
# dtypes → Displays the datatype of every column.
#
# Q.2  Data Cleaning
#
# a) Check for missing values in the dataset.
# b) Handle missing values appropriately.
# c) Identify categorical columns present in the dataset.
#
# ...>> # a) Check for missing values in the dataset
# print("Missing Values in Each Column:")
# print(df.isnull().sum())
#
# # b) Handle missing values appropriately
#
# # Separate numerical and categorical columns
# numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
# categorical_cols = df.select_dtypes(include=['object']).columns
#
# # Fill numerical missing values with median
# for col in numerical_cols:
#     df[col].fillna(df[col].median(), inplace=True)
#
# # Fill categorical missing values with mode
# for col in categorical_cols:
#     df[col].fillna(df[col].mode()[0], inplace=True)
#
# print("\nMissing Values After Handling:")
# print(df.isnull().sum())
#
# # c) Identify categorical columns present in the dataset
# print("\nCategorical Columns in Dataset:")
# print(list(categorical_cols))
# Explanation
# isnull().sum() → Checks total missing values in each column.
# select_dtypes() → Identifies numerical and categorical columns.
# Numerical missing values are filled using the median.
# Categorical missing values are filled using the mode.
# list(categorical_cols) → Displays all categorical columns.
#
# Q.3 . Exploratory Data Analysis (EDA)
#
# a) Plot the distribution of the target variable.
# b) Analyze the relationship between one numerical feature and the target variable.
# c) Analyze the relationship between Years of Employment and the target variable.
#
#
# ...>> # Import required libraries
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # -------------------------------
# # a) Distribution of Target Variable
# # -------------------------------
#
# # Replace 'Target' with your actual target column name
# target_column = 'Target'
#
# plt.figure(figsize=(8,5))
# sns.histplot(df[target_column], kde=True)
# plt.title('Distribution of Target Variable')
# plt.xlabel(target_column)
# plt.ylabel('Frequency')
# plt.show()
#
#
# # -------------------------------
# # b) Relationship Between One Numerical Feature and Target Variable
# # -------------------------------
#
# # Replace 'Age' with any numerical feature from your dataset
# numerical_feature = 'Age'
#
# plt.figure(figsize=(8,5))
# sns.scatterplot(x=df[numerical_feature], y=df[target_column])
# plt.title(f'{numerical_feature} vs {target_column}')
# plt.xlabel(numerical_feature)
# plt.ylabel(target_column)
# plt.show()
#
#
# # -------------------------------
# # c) Relationship Between Years of Employment and Target Variable
# # -------------------------------
#
# # Replace 'Years_of_Employment' with actual column name if different
# employment_column = 'Years_of_Employment'
#
# plt.figure(figsize=(8,5))
# sns.scatterplot(x=df[employment_column], y=df[target_column])
# plt.title(f'{employment_column} vs {target_column}')
# plt.xlabel(employment_column)
# plt.ylabel(target_column)
# plt.show()
# Explanation
# histplot() → Shows the distribution of the target variable.
# scatterplot() → Helps analyze relationships between numerical variables and the target.
# kde=True → Adds a smooth density curve to the histogram.
# Replace:
# 'Target' with your actual target column name
# 'Age' with any numerical feature
# 'Years_of_Employment' with the correct column name if different
# Insights You Can Observe
# Whether the target variable is normally distributed or skewed.
# Whether a numerical feature has a positive or negative relationship with the target.
# Whether more years of employment influence the target variable significantly.
#
# Q.4  Outlier Detection and Treatment
#
# a) Detect outliers in numerical columns using the IQR method.
# b) Treat outliers using capping techniques
#
#
#
# ...>> # Import required libraries
# import pandas as pd
# import numpy as np
#
# # Select numerical columns
# numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
#
# # ----------------------------------------
# # a) Detect Outliers Using IQR Method
# # ----------------------------------------
#
# print("Outlier Detection Using IQR Method:\n")
#
# for col in numerical_cols:
#
#     # Calculate Q1 and Q3
#     Q1 = df[col].quantile(0.25)
#     Q3 = df[col].quantile(0.75)
#
#     # Calculate IQR
#     IQR = Q3 - Q1
#
#     # Define lower and upper limits
#     lower_limit = Q1 - 1.5 * IQR
#     upper_limit = Q3 + 1.5 * IQR
#
#     # Detect outliers
#     outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)]
#
#     print(f"{col}: {len(outliers)} outliers detected")
#
#
# # ----------------------------------------
# # b) Treat Outliers Using Capping Technique
# # ----------------------------------------
#
# for col in numerical_cols:
#
#     # Calculate Q1 and Q3
#     Q1 = df[col].quantile(0.25)
#     Q3 = df[col].quantile(0.75)
#
#     # Calculate IQR
#     IQR = Q3 - Q1
#
#     # Define lower and upper limits
#     lower_limit = Q1 - 1.5 * IQR
#     upper_limit = Q3 + 1.5 * IQR
#
#     # Apply capping
#     df[col] = np.where(df[col] > upper_limit, upper_limit,
#                        np.where(df[col] < lower_limit, lower_limit, df[col]))
#
# print("\nOutliers have been treated using capping.")
# Explanation
# IQR Method
#
# IQR=Q
# 3
# 	​
#
# −Q
# 1
# 	​
#
#
# Q1 → 25th percentile
# Q3 → 75th percentile
# IQR → Interquartile Range
#
# Outlier limits:
#
# Lower Limit=Q
# 1
# 	​
#
# −1.5(IQR)
#
# Upper Limit=Q
# 3
# 	​
#
# +1.5(IQR)
#
# Capping Technique
# Values below the lower limit are replaced with the lower limit.
# Values above the upper limit are replaced with the upper limit.
# This helps reduce the effect of extreme values without removing records.
#
#
#
# Q.5  Convert target variables into numerical format suitable for model building and drop unnecessary columns.
#
# ...>> # Import required libraries
# from sklearn.preprocessing import LabelEncoder
#
# # -----------------------------------------
# # Convert Target Variable into Numerical Form
# # -----------------------------------------
#
# # Replace 'Target' with your actual target column name
# target_column = 'Target'
#
# # Create LabelEncoder object
# le = LabelEncoder()
#
# # Convert target column into numerical values
# df[target_column] = le.fit_transform(df[target_column])
#
# print("Target Variable After Encoding:")
# print(df[target_column].head())
#
#
# # -----------------------------------------
# # Identify and Drop Unnecessary Columns
# # -----------------------------------------
#
# # Example unnecessary columns
# # Replace these with actual column names if present
# columns_to_drop = ['Customer_ID', 'Name']
#
# # Drop columns only if they exist in dataset
# df.drop(columns=[col for col in columns_to_drop if col in df.columns],
#         inplace=True)
#
# print("\nRemaining Columns:")
# print(df.columns)
# Explanation
# Label Encoding
# LabelEncoder() converts categorical target values into numerical values.
# Example:
# Yes → 1
# No → 0
# Dropping Unnecessary Columns
#
# Common unnecessary columns include:
#
# ID columns
# Name columns
# Duplicate information columns
#
# These columns usually do not help in model prediction and may reduce model performance.
#
# Q.6 Feature Selection and Data Splitting
#
# a) Separate independent variables (X) and dependent variable (y)
# b) Split the dataset into training and testing sets.
#
# ...>> # Import required library
# from sklearn.model_selection import train_test_split
#
# # -----------------------------------------
# # a) Separate Independent and Dependent Variables
# # -----------------------------------------
#
# # Replace 'Target' with your actual target column name
# target_column = 'Target'
#
# # Independent variables (Features)
# X = df.drop(columns=[target_column])
#
# # Dependent variable (Target)
# y = df[target_column]
#
# print("Independent Variables (X):")
# print(X.head())
#
# print("\nDependent Variable (y):")
# print(y.head())
#
#
# # -----------------------------------------
# # b) Split Dataset into Training and Testing Sets
# # -----------------------------------------
#
# # Split the dataset
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.2,      # 20% testing data
#     random_state=42     # Ensures reproducibility
# )
#
# # Display shapes
# print("\nTraining Data Shape:")
# print(X_train.shape)
#
# print("\nTesting Data Shape:")
# print(X_test.shape)
#
# print("\nTraining Target Shape:")
# print(y_train.shape)
#
# print("\nTesting Target Shape:")
# print(y_test.shape)
# Explanation
# Feature Selection
# X → Independent variables (input features)
# y → Dependent variable (target/output)
# Data Splitting
# test_size=0.2 → 80% training data and 20% testing data
# random_state=42 → Produces consistent results every time the code runs
# Purpose
# Training data → Used to train the model
# Testing data → Used to evaluate model performance.
#
# Q.7 Apply feature scaling to the dataset using StandardScaler.
#
# ...>> # Import required library
# from sklearn.preprocessing import StandardScaler
#
# # -----------------------------------------
# # Apply Feature Scaling using StandardScaler
# # -----------------------------------------
#
# # Create StandardScaler object
# scaler = StandardScaler()
#
# # Scale training data
# X_train_scaled = scaler.fit_transform(X_train)
#
# # Scale testing data
# X_test_scaled = scaler.transform(X_test)
#
# # Convert scaled arrays back to DataFrame (optional)
# import pandas as pd
#
# X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
# X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
#
# # Display scaled data
# print("Scaled Training Data:")
# print(X_train_scaled.head())
#
# print("\nScaled Testing Data:")
# print(X_test_scaled.head())
# Explanation
# StandardScaler Formula
# z=
# σ
# x−μ
# 	​
#
# x
# μ
# σ
# z=
# σ
# x−μ
# 	​
#
# ≈1.2
# Φ(z)≈88.5%
#
# Where:
#
# x = Original value
# μ = Mean of the feature
# σ = Standard deviation
# Why Standardization?
# Converts data into a common scale
# Mean becomes approximately 0
# Standard deviation becomes approximately 1
# Improves performance of many machine learning algorithms such as:
# Logistic Regression
# KNN
# SVM
# Neural Networks.
#
# Q.8 Logistic Regression Model Building
#
# a) Train a Logistic Regression model.
# b) Predict the output for test data.
#
#
# ....>> # Import required libraries
# from sklearn.linear_model import LogisticRegression
#
# # -----------------------------------------
# # a) Train Logistic Regression Model
# # -----------------------------------------
#
# # Create Logistic Regression model
# log_model = LogisticRegression()
#
# # Train the model using scaled training data
# log_model.fit(X_train_scaled, y_train)
#
# print("Logistic Regression Model Trained Successfully!")
#
#
# # -----------------------------------------
# # b) Predict Output for Test Data
# # -----------------------------------------
#
# # Make predictions on test data
# y_pred = log_model.predict(X_test_scaled)
#
# # Display predictions
# print("\nPredicted Values:")
# print(y_pred)
# Explanation
# Logistic Regression
# Logistic Regression is mainly used for classification problems.
# It predicts the probability of a class/category.
# Logistic Function (Sigmoid Function)
#
# σ(z)=
# 1+e
# −z
# 1
# 	​
#
#
# Output values range between 0 and 1.
# Final class prediction is based on probability threshold (usually 0.5).
# Workflow
# Create model using LogisticRegression()
# Train model using fit()
# Predict results using predict().
#
# Q.9 Model Evaluation – Confusion Matrix
#
# a) Generate the confusion matrix.
# b) Interpret the results.
#
# ...>> # Import required libraries
# from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# import matplotlib.pyplot as plt
#
# # -----------------------------------------
# # a) Generate Confusion Matrix
# # -----------------------------------------
#
# # Create confusion matrix
# cm = confusion_matrix(y_test, y_pred)
#
# # Display confusion matrix
# print("Confusion Matrix:")
# print(cm)
#
# # Plot confusion matrix
# disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp.plot(cmap='Blues')
#
# plt.title("Confusion Matrix")
# plt.show()
# Example Confusion Matrix
#
# If the output is:
#
# [
# 50
# 5
# 	​
#
# 10
# 35
# 	​
#
# ]
#
# Then:
#
# Actual / Predicted	Predicted 0	Predicted 1
# Actual 0	50	10
# Actual 1	5	35
# b) Interpretation of Results
# True Positives (TP)
# Correctly predicted positive cases
# Here: 35
# True Negatives (TN)
# Correctly predicted negative cases
# Here: 50
# False Positives (FP)
# Incorrectly predicted as positive
# Here: 10
# False Negatives (FN)
# Incorrectly predicted as negative
# Here: 5
# Key Insight
# Higher TP and TN values indicate better model performance.
# Lower FP and FN values indicate fewer prediction errors.
# Confusion Matrix Structure
#
# [
# TN
# FN
# 	​
#
# FP
# TP
# 	​
#
# ]
#
#
#
# Q.10 . Model Evaluation – ROC Curve & AUC
#
# a) Plot the ROC curve.
# b) Calculate the AUC score.
#
# ....>> # Import required libraries
# from sklearn.metrics import roc_curve, roc_auc_score
# import matplotlib.pyplot as plt
#
# # -----------------------------------------
# # a) Plot ROC Curve
# # -----------------------------------------
#
# # Predict probabilities for positive class
# y_prob = log_model.predict_proba(X_test_scaled)[:, 1]
#
# # Calculate ROC curve values
# fpr, tpr, thresholds = roc_curve(y_test, y_prob)
#
# # Plot ROC Curve
# plt.figure(figsize=(8,6))
# plt.plot(fpr, tpr, label='ROC Curve')
#
# # Plot diagonal reference line
# plt.plot([0, 1], [0, 1], linestyle='--')
#
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve')
# plt.legend()
# plt.show()
#
#
# # -----------------------------------------
# # b) Calculate AUC Score
# # -----------------------------------------
#
# auc_score = roc_auc_score(y_test, y_prob)
#
# print("AUC Score:", auc_score)
# ROC Curve
# ROC stands for Receiver Operating Characteristic.
# It shows the performance of a classification model at different threshold values.
# ROC Axes
# X-axis → False Positive Rate (FPR)
# Y-axis → True Positive Rate (TPR)
# Important Formulas
#
# True Positive Rate:
#
# TPR=
# TP+FN
# TP
# 	​
#
#
# False Positive Rate:
#
# FPR=
# FP+TN
# FP
# 	​
#
#
# AUC Score
# AUC = Area Under the Curve
# Measures the model’s ability to distinguish between classes.
# Interpretation of AUC
# AUC Score	Model Performance
# 0.5	Poor
# 0.6 – 0.7	Fair
# 0.7 – 0.8	Good
# 0.8 – 0.9	Very Good
# 0.9 – 1.0	Excellent
